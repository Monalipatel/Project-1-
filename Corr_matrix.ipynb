# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress
import scipy.stats as st

# %%
df_2019 = pd.read_csv('Resources/2019.csv')

# %%
df_2019.head()
# Out:
#    Unnamed: 0      Country  Year  Happiness Rank  Happiness Score  \
# 0           0      Finland  2019               1            7.769
# 1           1      Denmark  2019               2            7.600
# 2           2       Norway  2019               3            7.554
# 3           3      Iceland  2019               4            7.494
# 4           4  Netherlands  2019               5            7.488
#
#    Economy (GDP per Capita)  Family/Social Support  Health (Life Expectancy)  \
# 0                     1.340                  1.587                     0.986
# 1                     1.383                  1.573                     0.996
# 2                     1.488                  1.582                     1.028
# 3                     1.380                  1.624                     1.026
# 4                     1.396                  1.522                     0.999
#
#    Freedom  Trust (Government Corruption)  Generosity
# ...

# %%
corr_matrix = df_2019[["Economy (GDP per Capita)", "Family/Social Support", "Health (Life Expectancy)", "Freedom", "Trust (Government Corruption)", "Generosity"]]
corr_matrix
# Out:
#      Economy (GDP per Capita)  Family/Social Support  \
# 0                       1.340                  1.587
# 1                       1.383                  1.573
# 2                       1.488                  1.582
# 3                       1.380                  1.624
# 4                       1.396                  1.522
# ..                        ...                    ...
# 151                     0.359                  0.711
# 152                     0.476                  0.885
# 153                     0.350                  0.517
# 154                     0.026                  0.000
# 155                     0.306                  0.575
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                       0.986    0.596                          0.393
# 1                       0.996    0.592                          0.410
# 2                       1.028    0.603                          0.341
# ...

# %%
corr_matrix.corr()
# Out:
#                                Economy (GDP per Capita)  \
# Economy (GDP per Capita)                       1.000000
# Family/Social Support                          0.754906
# Health (Life Expectancy)                       0.835462
# Freedom                                        0.379079
# Trust (Government Corruption)                  0.298920
# Generosity                                    -0.079662
#
#                                Family/Social Support  \
# Economy (GDP per Capita)                    0.754906
# Family/Social Support                       1.000000
# Health (Life Expectancy)                    0.719009
# Freedom                                     0.447333
# Trust (Government Corruption)               0.181899
# Generosity                                 -0.048126
#
#                                Health (Life Expectancy)   Freedom  \
# Economy (GDP per Capita)                       0.835462  0.379079
# ...

# %%
f = plt.figure(figsize=(15, 10))
plt.matshow(corr_matrix.corr(), fignum=f.number, data=True)
plt.xticks(range(corr_matrix.shape[1]), corr_matrix.columns, fontsize=10,rotation=90)
plt.yticks(range(corr_matrix.shape[1]), corr_matrix.columns, fontsize=10)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=10)

#plt.title('Correlation Matrix', fontsize=16);
png_filepath = "Images/Correlation Matrix.png"

plt.savefig(png_filepath)

# %% [markdown]
# # Analysis for Correlation Matrix

# %% [markdown]
# Happiness score essentially triple counts one factor that can be defined as either Health, GDP, or Family.
#
# If a country does well in any one these factors it will likely do well in the other 2, moving them up the list
# Conversely, if it does poorly in any one of these, it will likey do poorly in the other 2, moving them down the list.
