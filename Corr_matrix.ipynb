# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress
import scipy.stats as st

# %%
df_2019 = pd.read_csv('Resources/2019.csv')

# %%
df_2019.head()
# Out:
#        Country  Year  Happiness Rank  Happiness Score  \
# 0      Finland  2019               1            7.769
# 1      Denmark  2019               2            7.600
# 2       Norway  2019               3            7.554
# 3      Iceland  2019               4            7.494
# 4  Netherlands  2019               5            7.488
#
#    Economy (GDP per Capita)  Family/Social Support  Health (Life Expectancy)  \
# 0                     1.340                  1.587                     0.986
# 1                     1.383                  1.573                     0.996
# 2                     1.488                  1.582                     1.028
# 3                     1.380                  1.624                     1.026
# 4                     1.396                  1.522                     0.999
#
#    Freedom  Trust (Government Corruption)  Generosity
# 0    0.596                          0.153       0.393
# 1    0.592                          0.252       0.410
# 2    0.603                          0.271       0.341
# 3    0.591                          0.354       0.118
# 4    0.557                          0.322       0.298

# %%
column = ['Economy (GDP per Capita)',
        'Family/Social Support',
        'Health (Life Expectancy)',
        'Freedom',
        'Trust (Government Corruption)',
        'Generosity'
          ]
pd.read_csv(df_2019,delimiter =';',names = column)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-5b72d89614f0> in <module>
#       6         'Generosity'
#       7           ]
# ----> 8 pd.read_csv(df_2019,delimiter =';',names = column)
#       9
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438     # See https://github.com/python/mypy/issues/1297
#     439     fp_or_buf, _, compression, should_close = get_filepath_or_buffer(
# --> 440         filepath_or_buffer, encoding, compression
#     441     )
#     442     kwds["compression"] = compression
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     222     if not is_file_like(filepath_or_buffer):
#     223         msg = "Invalid file path or buffer object type: {_type}"
# --> 224         raise ValueError(msg.format(_type=type(filepath_or_buffer)))
#     225
#     226     return filepath_or_buffer, None, compression, False
#
# ValueError: Invalid file path or buffer object type: <class 'set'>

# %%
corrMatrix = df.corr()
print (corrMatrix)
# Out:
#                                Year  Happiness Rank  Happiness Score  \
# Year                            NaN             NaN              NaN
# Happiness Rank                  NaN        1.000000        -0.989096
# Happiness Score                 NaN       -0.989096         1.000000
# Economy (GDP per Capita)        NaN       -0.801947         0.793883
# Family/Social Support           NaN       -0.767465         0.777058
# Health (Life Expectancy)        NaN       -0.787411         0.779883
# Freedom                         NaN       -0.546606         0.566742
# Trust (Government Corruption)   NaN       -0.047993         0.075824
# Generosity                      NaN       -0.351959         0.385613
#
#                                Economy (GDP per Capita)  \
# Year                                                NaN
# Happiness Rank                                -0.801947
# Happiness Score                                0.793883
# Economy (GDP per Capita)                       1.000000
# Family/Social Support                          0.754906
# Health (Life Expectancy)                       0.835462
# Freedom                                        0.379079
# Trust (Government Corruption)                 -0.079662
# Generosity                                     0.298920
#
#                                Family/Social Support  \
# Year                                             NaN
# Happiness Rank                             -0.767465
# Happiness Score                             0.777058
# Economy (GDP per Capita)                    0.754906
# Family/Social Support                       1.000000
# Health (Life Expectancy)                    0.719009
# Freedom                                     0.447333
# Trust (Government Corruption)              -0.048126
# Generosity                                  0.181899
#
#                                Health (Life Expectancy)   Freedom  \
# Year                                                NaN       NaN
# Happiness Rank                                -0.787411 -0.546606
# Happiness Score                                0.779883  0.566742
# Economy (GDP per Capita)                       0.835462  0.379079
# Family/Social Support                          0.719009  0.447333
# Health (Life Expectancy)                       1.000000  0.390395
# Freedom                                        0.390395  1.000000
# Trust (Government Corruption)                 -0.029511  0.269742
# Generosity                                     0.295283  0.438843
#
#                                Trust (Government Corruption)  Generosity
# Year                                                     NaN         NaN
# Happiness Rank                                     -0.047993   -0.351959
# Happiness Score                                     0.075824    0.385613
# Economy (GDP per Capita)                           -0.079662    0.298920
# Family/Social Support                              -0.048126    0.181899
# Health (Life Expectancy)                           -0.029511    0.295283
# Freedom                                             0.269742    0.438843
# Trust (Government Corruption)                       1.000000    0.326538
# Generosity                                          0.326538    1.000000

# %%
corr_matrix.corr()
