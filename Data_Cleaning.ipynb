# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %%
df_2015_raw = pd.read_csv('Resources/2015_raw.csv')
df_2016_raw = pd.read_csv('Resources/2016_raw.csv')
df_2017_raw = pd.read_csv('Resources/2017_raw.csv')
df_2018_raw = pd.read_csv('Resources/2018_raw.csv')
df_2019_raw = pd.read_csv('Resources/2019_raw.csv')

# %% [markdown]
# ## 2015 Data

# %%
df_2015_raw.info()
df_2015_raw.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df_2015_raw = df_2015_raw[["Country", "Happiness Rank", "Happiness Score", "Economy (GDP per Capita)", "Family", "Health (Life Expectancy)", "Freedom", "Trust (Government Corruption)", "Generosity"]]
df_2015_raw["Year"] = "2015"
df_2015_raw = df_2015_raw.rename(columns={"Family":"Family/Social Support"})
df_2015 = df_2015_raw[["Country", "Year", "Happiness Rank", "Happiness Score", "Economy (GDP per Capita)", "Family/Social Support", "Health (Life Expectancy)", "Freedom", "Trust (Government Corruption)", "Generosity"]]
df_2015
# Out:
#          Country  Year  Happiness Rank  Happiness Score  \
# 0    Switzerland  2015               1            7.587
# 1        Iceland  2015               2            7.561
# 2        Denmark  2015               3            7.527
# 3         Norway  2015               4            7.522
# 4         Canada  2015               5            7.427
# ..           ...   ...             ...              ...
# 153       Rwanda  2015             154            3.465
# 154        Benin  2015             155            3.340
# 155        Syria  2015             156            3.006
# 156      Burundi  2015             157            2.905
# 157         Togo  2015             158            2.839
#
#      Economy (GDP per Capita)  Family/Social Support  \
# 0                     1.39651                1.34951
# 1                     1.30232                1.40223
# 2                     1.32548                1.36058
# 3                     1.45900                1.33095
# ...

# %%
df_2015.to_csv("Resources/2015.csv")

# %% [markdown]
# ## 2016 Data

# %%
df_2016_raw.info()
df_2016_raw.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
df_2016_raw = df_2016_raw[["Country", "Happiness Rank", "Happiness Score", "Economy (GDP per Capita)", "Family", "Health (Life Expectancy)", "Freedom", "Trust (Government Corruption)", "Generosity"]]
df_2016_raw["Year"] = "2016"
df_2016_raw = df_2016_raw.rename(columns={"Family":"Family/Social Support"})
df_2016 = df_2016_raw[["Country", "Year", "Happiness Rank", "Happiness Score", "Economy (GDP per Capita)", "Family/Social Support", "Health (Life Expectancy)", "Freedom", "Trust (Government Corruption)", "Generosity"]]
df_2016
# Out:
#          Country  Year  Happiness Rank  Happiness Score  \
# 0        Denmark  2016               1            7.526
# 1    Switzerland  2016               2            7.509
# 2        Iceland  2016               3            7.501
# 3         Norway  2016               4            7.498
# 4        Finland  2016               5            7.413
# ..           ...   ...             ...              ...
# 152        Benin  2016             153            3.484
# 153  Afghanistan  2016             154            3.360
# 154         Togo  2016             155            3.303
# 155        Syria  2016             156            3.069
# 156      Burundi  2016             157            2.905
#
#      Economy (GDP per Capita)  Family/Social Support  \
# 0                     1.44178                1.16374
# 1                     1.52733                1.14524
# 2                     1.42666                1.18326
# 3                     1.57744                1.12690
# ...

# %%
df_2016.to_csv("Resources/2016.csv")

# %% [markdown]
# ## 2017 Data

# %%
df_2017_raw.info()
df_2017_raw.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
df_2017_raw = df_2017_raw[["Country", "Happiness.Rank", "Happiness.Score", "Economy..GDP.per.Capita.", "Family", "Health..Life.Expectancy.", "Freedom", "Trust..Government.Corruption.", "Generosity"]]
df_2017_raw = df_2017_raw.rename(columns={"Happiness.Rank": "Happiness Rank", "Happiness.Score": "Happiness Score", "Economy..GDP.per.Capita.": "Economy (GDP per Capita)", "Family": "Family/Social Support", "Health..Life.Expectancy.": "Health (Life Expectancy)", "Freedom": "Freedom", "Generosity": "Generosity", "Trust..Government.Corruption.": "Trust (Government Corruption)"})
df_2017_raw["Year"] = "2017"
df_2017= df_2017_raw[["Country", "Year", "Happiness Rank", "Happiness Score", "Economy (GDP per Capita)", "Family/Social Support", "Health (Life Expectancy)", "Freedom", "Trust (Government Corruption)", "Generosity"]]
df_2017
# Out:
#                       Country  Year  Happiness Rank  Happiness Score  \
# 0                      Norway  2017               1            7.537
# 1                     Denmark  2017               2            7.522
# 2                     Iceland  2017               3            7.504
# 3                 Switzerland  2017               4            7.494
# 4                     Finland  2017               5            7.469
# ..                        ...   ...             ...              ...
# 150                    Rwanda  2017             151            3.471
# 151                     Syria  2017             152            3.462
# 152                  Tanzania  2017             153            3.349
# 153                   Burundi  2017             154            2.905
# 154  Central African Republic  2017             155            2.693
#
#      Economy (GDP per Capita)  Family/Social Support  \
# 0                    1.616463               1.533524
# ...

# %%
df_2017.to_csv("Resources/2017.csv")

# %% [markdown]
# ## 2018 Data

# %%
df_2018_raw.info()
df_2018_raw.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# ...

# %%
df_2018_raw = df_2018_raw[["Country or region", "Overall rank", "Score", "GDP per capita", "Social support", "Healthy life expectancy", "Freedom to make life choices", "Perceptions of corruption", "Generosity"]]
df_2018_raw = df_2018_raw.rename(columns={"Country or region": "Country", "Overall rank": "Happiness Rank", "Score": "Happiness Score" , "GDP per capita": "Economy (GDP per Capita)", "Social support": "Family/Social Support", "Healthy life expectancy": "Health (Life Expectancy)", "Freedom to make life choices": "Freedom", "Perceptions of corruption": "Trust (Government Corruption)", "Generosity": "Generosity"})
df_2018_raw["Year"] = "2018"
df_2018= df_2018_raw[["Country", "Year", "Happiness Rank", "Happiness Score", "Economy (GDP per Capita)", "Family/Social Support", "Health (Life Expectancy)", "Freedom", "Trust (Government Corruption)", "Generosity"]]
df_2018
# Out:
#                       Country  Year  Happiness Rank  Happiness Score  \
# 0                     Finland  2018               1            7.632
# 1                      Norway  2018               2            7.594
# 2                     Denmark  2018               3            7.555
# 3                     Iceland  2018               4            7.495
# 4                 Switzerland  2018               5            7.487
# ..                        ...   ...             ...              ...
# 151                     Yemen  2018             152            3.355
# 152                  Tanzania  2018             153            3.303
# 153               South Sudan  2018             154            3.254
# 154  Central African Republic  2018             155            3.083
# 155                   Burundi  2018             156            2.905
#
#      Economy (GDP per Capita)  Family/Social Support  \
# 0                       1.305                  1.592
# ...

# %%
df_2018.to_csv("Resources/2018.csv")

# %% [markdown]
# ## 2019 Data

# %%
df_2019_raw.info()
df_2019_raw.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# ...

# %%
df_2019_raw = df_2019_raw[["Country or region", "Overall rank", "Score", "GDP per capita", "Social support", "Healthy life expectancy", "Freedom to make life choices", "Perceptions of corruption", "Generosity"]]
df_2019_raw = df_2019_raw.rename(columns={"Country or region": "Country", "Overall rank": "Happiness Rank", "Score": "Happiness Score" , "GDP per capita": "Economy (GDP per Capita)", "Social support": "Family/Social Support", "Healthy life expectancy": "Health (Life Expectancy)", "Freedom to make life choices": "Freedom", "Perceptions of corruption": "Trust (Government Corruption)", "Generosity": "Generosity"})
df_2019_raw["Year"] = "2019"
df_2019= df_2019_raw[["Country", "Year", "Happiness Rank", "Happiness Score", "Economy (GDP per Capita)", "Family/Social Support", "Health (Life Expectancy)", "Freedom", "Trust (Government Corruption)", "Generosity"]]
df_2019
# Out:
#                       Country  Year  Happiness Rank  Happiness Score  \
# 0                     Finland  2019               1            7.769
# 1                     Denmark  2019               2            7.600
# 2                      Norway  2019               3            7.554
# 3                     Iceland  2019               4            7.494
# 4                 Netherlands  2019               5            7.488
# ..                        ...   ...             ...              ...
# 151                    Rwanda  2019             152            3.334
# 152                  Tanzania  2019             153            3.231
# 153               Afghanistan  2019             154            3.203
# 154  Central African Republic  2019             155            3.083
# 155               South Sudan  2019             156            2.853
#
#      Economy (GDP per Capita)  Family/Social Support  \
# 0                       1.340                  1.587
# ...

# %%
df_2019.to_csv("Resources/2018.csv")
