# %% [markdown]
# # Scatter Plots

# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress
import scipy.stats as st

# %%
# Study data files
df_2019 = pd.read_csv('Resources/2019.csv')

# %%
# Create dataFrame
df_2019.head()
# Out:
#        Country  Year  Happiness Rank  Happiness Score  \
# 0      Finland  2019               1            7.769
# 1      Denmark  2019               2            7.600
# 2       Norway  2019               3            7.554
# 3      Iceland  2019               4            7.494
# 4  Netherlands  2019               5            7.488
#
#    Economy (GDP per Capita)  Family/Social Support  Health (Life Expectancy)  \
# 0                     1.340                  1.587                     0.986
# 1                     1.383                  1.573                     0.996
# 2                     1.488                  1.582                     1.028
# 3                     1.380                  1.624                     1.026
# 4                     1.396                  1.522                     0.999
#
#    Freedom  Trust (Government Corruption)  Generosity
# 0    0.596                          0.153       0.393
# 1    0.592                          0.252       0.410
# ...

# %%
# Function for Scatter plots 

def scatter_plot(x_values, y_values, x_label, ylabel, title, line_loc, png_filepath):
    plt.figure(figsize=(6, 5), dpi=80)
    plt.style.use("ggplot")
    plt.scatter(x_values, y_values, c="salmon", alpha = 0.75, edgecolors="grey", s=250)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.plot(x_values,regress_values,"navy")
    plt.annotate(line_eq,line_loc,fontsize=13,color="navy")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    plt.savefig(png_filepath)
    plt.show()

# %% [markdown]
# # Economy - Scatter

# %%
# Correlation of Economy and Family/Social Support
x_values = df_2019["Economy (GDP per Capita)"]
y_values = df_2019["Family/Social Support"]
xlabel = "Economy (GDP per Capita)"
ylabel = "Family/Social Support"
title = "Correlation of Economy and Family/Social Support"
line_loc = (1,0)
png_filepath = "Images/Eco_vs_Fam_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.75

# %%
# Correlation of Economy and Health (Life Expectancy)
x_values = df_2019["Economy (GDP per Capita)"]
y_values = df_2019["Health (Life Expectancy)"]
xlabel = "Economy (GDP per Capita)"
ylabel = "Health (Life Expectancy)"
title = "Correlation of Economy and Health (Life Expectancy)"
line_loc = (1,0)
png_filepath = "Images/Eco_vs_Life_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.84

# %%
# Correlation of Economy and Freedom
x_values = df_2019["Economy (GDP per Capita)"]
y_values = df_2019["Freedom"]
xlabel = "Economy (GDP per Capita)"
ylabel = "Freedom"
title = "Correlation of Economy and Freedom"
line_loc = (1,0)
png_filepath = "Images/Eco_vs_Free_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.38

# %%
# Correlation of Economy and Trust (Government Corruption)
x_values = df_2019["Economy (GDP per Capita)"]
y_values = df_2019["Trust (Government Corruption)"]
xlabel = "Economy (GDP per Capita)"
ylabel = "Trust (Government Corruption)"
title = "Correlation of Economy and Trust (Government Corruption)"
line_loc = (1,0.58)
png_filepath = "Images/Eco_vs_Trust_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is -0.08

# %%
# Correlation of Economy and Generosity 
x_values = df_2019["Economy (GDP per Capita)"]
y_values = df_2019["Generosity"]
xlabel = "Economy (GDP per Capita)"
ylabel = "Generosity"
title = "Correlation of Economy and Generosity"
line_loc = (1,0.47)
png_filepath = "Images/Eco_vs_Gen_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.3

# %% [markdown]
# # Family - Scatter

# %%
# Correlation of Family/Social Support and Health (Life Expectancy)
x_values = df_2019["Family/Social Support"]
y_values = df_2019["Health (Life Expectancy)"]
xlabel = "Family/Social Support"
ylabel = "Health (Life Expectancy)"
title = "Correlation of Family/Social Support and Health (Life Expectancy)"
line_loc = (0.15,0)
png_filepath = "Images/Family_vs_Life_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.72

# %%
# Correlation of Family/Social Support and Freedom
x_values = df_2019["Family/Social Support"]
y_values = df_2019["Freedom"]
xlabel = "Family/Social Support"
ylabel = "Freedom"
title = "Correlation of Family/Social Support and Freedom"
line_loc = (1,-0.02)
png_filepath = "Images/Family_vs_Free_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.45

# %%
# Correlation of Family/Social Support and Trust (Government Corruption)
x_values = df_2019["Family/Social Support"]
y_values = df_2019["Trust (Government Corruption)"]
xlabel = "Family/Social Support"
ylabel = "Trust (Government Corruption)"
title = "Correlation of Family/Social Support and Trust (Government Corruption)"
line_loc = (0,0)
png_filepath = "Images/Family_vs_Trust_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is -0.05

# %%
# Correlation of Family/Social Support and Generosity
x_values = df_2019["Family/Social Support"]
y_values = df_2019["Generosity"]
xlabel = "Family/Social Support"
ylabel = "Generosity"
title = "Correlation of Family/Social Support and Generosity"
line_loc = (0,-0.02)
png_filepath = "Images/Family_vs_Gen_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.18

# %% [markdown]
# # Health - Scatter

# %%
# Correlation of Health (Life Expectancy) and Freedom
x_values = df_2019["Health (Life Expectancy)"]
y_values = df_2019["Freedom"]
xlabel = "Health (Life Expectancy)"
ylabel = "Freedom"
title = "Correlation of Health (Life Expectancy) and Freedom"
line_loc = (0.75,0)
png_filepath = "Images/Health_vs_Free_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.39

# %%
# Correlation of Health (Life Expectancy) and Trust (Government Corruption)
x_values = df_2019["Health (Life Expectancy)"]
y_values = df_2019["Trust (Government Corruption)"]
xlabel = "Health (Life Expectancy)"
ylabel = "Trust (Government Corruption)"
title = "Correlation of Health (Life Expectancy) and Trust (Government Corruption)"
line_loc = (0.75,0.57)
png_filepath = "Images/Health_vs_Trust_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is -0.03

# %%
# Correlation of Health (Life Expectancy) and Generosity
x_values = df_2019["Health (Life Expectancy)"]
y_values = df_2019["Generosity"]
xlabel = "Health (Life Expectancy)"
ylabel = "Generosity"
title = "Correlation of Health (Life Expectancy) and Generosity"
line_loc = (0,0.47)
png_filepath = "Images/Health_vs_Gen_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.3

# %% [markdown]
# # Freedom Scatter

# %%
# Correlation of Freedom and Trust (Government Corruption)
x_values = df_2019["Freedom"]
y_values = df_2019["Trust (Government Corruption)"]
xlabel = "Freedom"
ylabel = "Trust (Government Corruption)"
title = "Correlation of Freedom and Trust (Government Corruption)"
line_loc = (0,0.57)
png_filepath = "Images/Freedom_vs_Trust_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.27

# %%
# Correlation of Freedom and Generosity
x_values = df_2019["Freedom"]
y_values = df_2019["Generosity"]
xlabel = "Freedom"
ylabel = "Generosity"
title = "Correlation of Freedom and Generosity" 
line_loc = (0,0.45)
png_filepath = "Images/Freedom_vs_Gen_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.44

# %% [markdown]
# # Trust (Government Corruption)

# %%
# Correlation of Trust (Government Corruption) and Generosity
x_values = df_2019["Trust (Government Corruption)"]
y_values = df_2019["Generosity"]
xlabel = "Trust (Government Corruption)"
ylabel = "Generosity"
title = "Correlation of Trust (Government Corruption) and Generosity" 
line_loc = (0.38,0.45)
png_filepath = "Images/Trust_vs_Gen_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.33

# %%
# Correlation of Trust (Government Corruption) and Generosity
x_values = df_2019["Generosity"]
y_values = df_2019["Trust (Government Corruption)"]
xlabel = "Generosity"
ylabel = "Trust (Government Corruption)"
title = "Correlation of Trust (Government Corruption) and Generosity" 
line_loc = (0.3,0.55)
png_filepath = "Images/Trust_vs_Gen_Scatter.png"

scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.33

# %% [markdown]
# # Happiness Score - Scatter

# %%
def hap_scatter_plot(x_values, y_values, x_label, ylabel, title, line_loc, png_filepath):
    plt.figure(figsize=(6, 5), dpi=80)
    plt.style.use("ggplot")
    plt.scatter(x_values, y_values, c="goldenrod", alpha = 0.75, edgecolors="grey", s=250)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.plot(x_values,regress_values,"navy")
    plt.annotate(line_eq,line_loc,fontsize=13,color="navy")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    plt.savefig(png_filepath)
    plt.show()

# %%
# Correlation of Happiness Score and Economy (GDP per Capita)
x_values = df_2019["Happiness Score"]
y_values = df_2019["Economy (GDP per Capita)"]
xlabel = "Happiness Score"
ylabel = "Economy (GDP per Capita)"
title = "Correlation of Happiness Score and Economy (GDP per Capita)" 
line_loc = (5.5,0)
png_filepath = "Images/Hap_vs_Eco_Scatter.png"

hap_scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.79

# %%
# Correlation of Happiness Score and Health (Life Expectancy)
x_values = df_2019["Happiness Score"]
y_values = df_2019["Health (Life Expectancy)"]
xlabel = "Happiness Score"
ylabel = "Health (Life Expectancy)"
title = "Correlation of Happiness Score and Health (Life Expectancy)" 
line_loc = (5.5,0)
png_filepath = "Images/Hap_vs_Hea_Scatter.png"

hap_scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.78

# %%
# Correlation of Happiness Score and Family/Social Support
x_values = df_2019["Happiness Score"]
y_values = df_2019["Family/Social Support"]
xlabel = "Happiness Score"
ylabel = "Family/Social Support"
title = "Correlation of Happiness Score and Family/Social Support" 
line_loc = (5.5,0)
png_filepath = "Images/Hap_vs_Family_Scatter.png"

hap_scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.78

# %%
# Correlation of Happiness Score and Freedom
x_values = df_2019["Happiness Score"]
y_values = df_2019["Freedom"]
xlabel = "Happiness Score"
ylabel = "Freedom"
title = "Correlation of Happiness Score and Freedom" 
line_loc = (5.5,0)
png_filepath = "Images/Hap_vs_Free_Scatter.png"

hap_scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.57

# %%
# Correlation of Happiness Score and Trust (Government Corruption)
x_values = df_2019["Happiness Score"]
y_values = df_2019["Trust (Government Corruption)"]
xlabel = "Happiness Score"
ylabel = "Trust (Government Corruption)"
title = "Correlation of Happiness Score and Trust (Government Corruption)" 
line_loc = (5.5,0)
png_filepath = "Images/Hap_vs_Trust_Scatter.png"

hap_scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.08

# %%
# Correlation of Happiness Score and Generosity
x_values = df_2019["Happiness Score"]
y_values = df_2019["Generosity"]
xlabel = "Happiness Score"
ylabel = "Generosity"
title = "Correlation of Happiness Score and Generosity" 
line_loc = (5.5,0)
png_filepath = "Images/Hap_vs_Gen_Scatter.png"

hap_scatter_plot(x_values, y_values, xlabel, ylabel, title, line_loc, png_filepath)
# Out:
# The correlation between both factors is 0.39
